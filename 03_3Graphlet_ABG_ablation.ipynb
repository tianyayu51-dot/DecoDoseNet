# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.utils.data import DataLoader, Dataset, Subset, random_split
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, precision_recall_curve, balanced_accuracy_score
import pandas as pd
import random
import numpy as np
import math
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from torch.utils.data import DataLoader, TensorDataset
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import os
import pickle


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error 
from scipy.stats import pearsonr
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA  


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

SEED = 42
ABLATION_MODES = ('idb_only', 'hpb_only')

def set_global_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_global_seed(SEED)


DATA_DIR = Path(r"E:\Research\DecoDoseNet\code\data")


def load_data():
    data_paths = {
        'combination_response': DATA_DIR / 'processed_combination_response_r070_clean_with_qc.csv',
        'drug_features': DATA_DIR / 'Graphlet_features_6_standardized.csv',
        'cell_features': DATA_DIR / 'cell_features_977d.csv'
    }

    print(f"Notebook working directory: {Path.cwd()}")
    print(f"Data directory: {DATA_DIR}")

    missing_files = [path for path in data_paths.values() if not path.is_file()]
    if missing_files:
        missing_text = '\n'.join(f'  - {path}' for path in missing_files)
        raise FileNotFoundError(
            'Required data files were not found.\n'
            f'Please check the DATA_DIR setting: {DATA_DIR}\n'
            f'Missing files:\n{missing_text}'
        )

    combo_df = pd.read_csv(data_paths['combination_response'], encoding='utf-8-sig')

    combo_df = combo_df.rename(columns={
        'target': 'X/X0',
        'drugA_conc': 'drugA Conc (µM)',
        'drugB_conc': 'drugB Conc (µM)'
    })

    combo_df['drugA_name'] = combo_df['drugA_name'].astype(str).str.strip().str.upper()
    combo_df['drugB_name'] = combo_df['drugB_name'].astype(str).str.strip().str.upper()
    combo_df['cell_line'] = combo_df['cell_line'].astype(str).str.strip()

    drug_features = pd.read_csv(data_paths['drug_features'], encoding='utf-8-sig')
    drug_features['name'] = drug_features['name'].astype(str).str.strip().str.upper()
    drug_features.set_index('name', inplace=True)

    cell_features = pd.read_csv(data_paths['cell_features'], encoding='utf-8-sig')
    cell_features['Cell_Line'] = cell_features['Cell_Line'].astype(str).str.strip()
    cell_features.set_index('Cell_Line', inplace=True)

    return combo_df, drug_features, cell_features


def preprocess_data(combo_df, drug_features, cell_features):
    valid_mask = (
        combo_df['drugA_name'].isin(drug_features.index) &
        combo_df['drugB_name'].isin(drug_features.index) &
        combo_df['cell_line'].isin(cell_features.index)
    )

    skipped_count = len(combo_df) - valid_mask.sum()
    print(f"Skipped {skipped_count} samples due to missing features")

    data_df = combo_df.loc[valid_mask, [
        'drugA_name', 'drugB_name', 'cell_line',
        'drugA Conc (µM)', 'drugB Conc (µM)',
        'X/X0', 'single_resp_1', 'single_resp_2'
    ]].copy()

    data_df = data_df.rename(columns={
        'drugA Conc (µM)': 'drugA_conc',
        'drugB Conc (µM)': 'drugB_conc',
        'X/X0': 'target'
    })

    return data_df.reset_index(drop=True)


def add_surface_id(data_df):
    """为每个 Drug pair + Cell line 构造唯一分组标识。

    药物名称先按字典序规范化，因此 (A, B, Cell) 与 (B, A, Cell)
    会被视为同一个药物组合曲面，避免药物顺序倒置造成隐性泄露。
    """
    grouped_df = data_df.copy()
    drug_pairs = np.sort(
        grouped_df[['drugA_name', 'drugB_name']].astype(str).to_numpy(),
        axis=1
    )
    grouped_df['surface_id'] = (
        drug_pairs[:, 0] + '||' + drug_pairs[:, 1] + '||' +
        grouped_df['cell_line'].astype(str).to_numpy()
    )
    return grouped_df


def grouped_train_val_test_split(
    data_df, train_size=0.70, val_size=0.10, test_size=0.20, random_state=42
):
    """按 surface_id 分组划分；同一曲面的所有剂量点只属于一个集合。"""
    if not np.isclose(train_size + val_size + test_size, 1.0):
        raise ValueError('train_size + val_size + test_size must equal 1.0')
    if min(train_size, val_size, test_size) <= 0:
        raise ValueError('train_size, val_size and test_size must all be positive')

    grouped_df = add_surface_id(data_df)

    outer_split = GroupShuffleSplit(
        n_splits=1, test_size=test_size, random_state=random_state
    )
    train_val_idx, test_idx = next(
        outer_split.split(grouped_df, groups=grouped_df['surface_id'])
    )
    train_val_df = grouped_df.iloc[train_val_idx].copy()
    test_df = grouped_df.iloc[test_idx].copy()


    relative_val_size = val_size / (train_size + val_size)
    inner_split = GroupShuffleSplit(
        n_splits=1, test_size=relative_val_size, random_state=random_state + 1
    )
    train_idx, val_idx = next(
        inner_split.split(train_val_df, groups=train_val_df['surface_id'])
    )
    train_df = train_val_df.iloc[train_idx].copy().reset_index(drop=True)
    val_df = train_val_df.iloc[val_idx].copy().reset_index(drop=True)
    test_df = test_df.reset_index(drop=True)


    train_groups = set(train_df['surface_id'])
    val_groups = set(val_df['surface_id'])
    test_groups = set(test_df['surface_id'])
    overlaps = {
        'train_val': train_groups & val_groups,
        'train_test': train_groups & test_groups,
        'val_test': val_groups & test_groups
    }
    assert all(len(x) == 0 for x in overlaps.values()), (
        f'Group leakage detected: { {k: len(v) for k, v in overlaps.items()} }'
    )
    assert len(train_df) + len(val_df) + len(test_df) == len(grouped_df)
    assert train_groups | val_groups | test_groups == set(grouped_df['surface_id'])

    split_summary = pd.DataFrame({
        'split': ['Train', 'Validation', 'Test'],
        'samples': [len(train_df), len(val_df), len(test_df)],
        'surface_groups': [len(train_groups), len(val_groups), len(test_groups)]
    })
    split_summary['sample_percent'] = (
        split_summary['samples'] / len(grouped_df) * 100
    ).round(2)
    split_summary['group_percent'] = (
        split_summary['surface_groups'] / grouped_df['surface_id'].nunique() * 100
    ).round(2)

    print('\nGrouped split summary (Drug pair + Cell line):')
    print(split_summary.to_string(index=False))
    print('\nLeakage audit passed:')
    print('  Train ∩ Validation groups = 0')
    print('  Train ∩ Test groups       = 0')
    print('  Validation ∩ Test groups  = 0')

    return train_df, val_df, test_df, split_summary


class DrugCombinationDataset(Dataset):
    def __init__(self, data, drug_features, cell_features):
        self.data = data.reset_index(drop=True)

        self.drug_features = {
            name: row.values[2:].astype(np.float32)
            for name, row in drug_features.iterrows()
        }

        self.cell_features = {
            name: row.values.astype(np.float32)
            for name, row in cell_features.iterrows()
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data.iloc[idx]

        drugA_feat = self.drug_features[sample['drugA_name']]
        drugB_feat = self.drug_features[sample['drugB_name']]
        cell_feat = self.cell_features[sample['cell_line']]

        combo_feat = np.concatenate([drugA_feat, drugB_feat, cell_feat]).astype(np.float32)

        return {
            'drugA_feat': torch.from_numpy(drugA_feat),
            'drugB_feat': torch.from_numpy(drugB_feat),
            'cell_feat': torch.from_numpy(cell_feat),
            'combo_feat': torch.from_numpy(combo_feat),
            'target': torch.tensor(sample['target'], dtype=torch.float32),
            'drugA_conc': torch.tensor(sample['drugA_conc'], dtype=torch.float32),
            'drugB_conc': torch.tensor(sample['drugB_conc'], dtype=torch.float32),
            'single_resp_1': torch.tensor(sample['single_resp_1'], dtype=torch.float32),
            'single_resp_2': torch.tensor(sample['single_resp_2'], dtype=torch.float32),
            'index': idx,
            'drugA_name': sample['drugA_name'],
            'drugB_name': sample['drugB_name'],
            'cell_line': sample['cell_line']
        }


class DrugCombinationModel(nn.Module):
    def __init__(self, drug_feat_dim=1000, cell_feat_dim=977):  
        super(DrugCombinationModel, self).__init__()
        

        self.drug_encoder = nn.Sequential(
            nn.Linear(drug_feat_dim, 1024),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU()
        )
        

        self.cell_encoder = nn.Sequential(
            nn.Linear(cell_feat_dim, 512),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            # nn.Dropout(0.3)
        )
        

        self.theta1_net = nn.Sequential(
            nn.Linear(256 + 256 + 1, 512),  
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
        

        self.theta2_net = nn.Sequential(
            nn.Linear(256 + 256 + 1, 512),  
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
        

        self.epsilon_net = nn.Sequential(
            nn.Linear(256 * 3 + 256 + 2, 1024),  
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.ReLU(),
            # nn.Dropout(0.3),
            nn.Linear(512, 1)
        )
        

        self.dose_encoder = nn.Sequential(
            nn.Linear(1, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU()
        )


        hpb_input_dim = 256 + 256 + 256 + 32 + 32  # 832

        self.predictor_direct = nn.Sequential(
            nn.Linear(hpb_input_dim, 2048),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
        
    def forward(self, drugA_feat, drugB_feat, cell_feat, combo_feat, drugA_conc, drugB_conc):

        encoded_drugA = self.drug_encoder(drugA_feat)
        encoded_drugB = self.drug_encoder(drugB_feat)
        encoded_cell = self.cell_encoder(cell_feat)
        

        theta1_input = torch.cat([encoded_drugA, encoded_cell, drugA_conc.unsqueeze(1)], dim=1)
        theta1_raw = self.theta1_net(theta1_input)
        

        theta2_input = torch.cat([encoded_drugB, encoded_cell, drugB_conc.unsqueeze(1)], dim=1)
        theta2_raw = self.theta2_net(theta2_input)
        

        drug_pair_sum = encoded_drugA + encoded_drugB
        drug_pair_product = encoded_drugA * encoded_drugB
        drug_pair_abs_difference = torch.abs(encoded_drugA - encoded_drugB)
        epsilon_input = torch.cat([drug_pair_sum, drug_pair_product, drug_pair_abs_difference, encoded_cell, 
                               drugA_conc.unsqueeze(1), drugB_conc.unsqueeze(1)], dim=1)
        epsilon = self.epsilon_net(epsilon_input)


        theta12_sum = theta1_raw + theta2_raw
        theta1 = theta1_raw / theta12_sum
        theta2 = theta2_raw / theta12_sum


        encoded_doseA = self.dose_encoder(drugA_conc.unsqueeze(1))
        encoded_doseB = self.dose_encoder(drugB_conc.unsqueeze(1))


        combined_features = torch.cat([
            encoded_drugA,
            encoded_drugB,
            encoded_cell,
            encoded_doseA,
            encoded_doseB
        ], dim=1)
        P_direct = self.predictor_direct(combined_features)

        return theta1.squeeze(-1), theta2.squeeze(-1), epsilon.squeeze(-1),P_direct.squeeze(-1)

def select_ablation_prediction(P_idb, P_hpb, ablation_mode):
    """为两种消融设置选择训练和评估时使用的预测。"""
    if ablation_mode == 'idb_only':
        return P_idb
    if ablation_mode == 'hpb_only':
        return P_hpb
    raise ValueError(f'Unknown ablation_mode: {ablation_mode}')


def concordance_index(y_true, y_pred):
    """计算连续结局的C-index；真实值相同的样本对不参与比较。"""
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    finite = np.isfinite(y_true) & np.isfinite(y_pred)
    y_true, y_pred = y_true[finite], y_pred[finite]
    if len(y_true) < 2:
        return np.nan

    order = np.argsort(y_true, kind='mergesort')
    y_true, y_pred = y_true[order], y_pred[order]
    _, pred_rank = np.unique(y_pred, return_inverse=True)
    pred_rank = pred_rank + 1
    tree = np.zeros(pred_rank.max() + 1, dtype=np.int64)

    def bit_add(index):
        while index < len(tree):
            tree[index] += 1
            index += index & -index

    def bit_sum(index):
        total = 0
        while index > 0:
            total += tree[index]
            index -= index & -index
        return total

    concordant = 0.0
    comparable = 0
    previous_count = 0
    start = 0
    while start < len(y_true):
        end = start + 1
        while end < len(y_true) and y_true[end] == y_true[start]:
            end += 1
        for rank in pred_rank[start:end]:
            lower = bit_sum(rank - 1)
            equal = bit_sum(rank) - lower
            concordant += lower + 0.5 * equal
            comparable += previous_count
        for rank in pred_rank[start:end]:
            bit_add(rank)
        previous_count += end - start
        start = end

    return concordant / comparable if comparable else np.nan


def train_model(model, train_loader, val_loader, train_df, val_df, ablation_mode, epochs=100, lr=5e-5,early_stop_patience=10,min_delta=1e-6):
    if ablation_mode not in ABLATION_MODES:
        raise ValueError(f'ablation_mode must be one of {ABLATION_MODES}')
    checkpoint_path = f'best_model_ablation_{ablation_mode}_seed{SEED}.pth'
    criterion = nn.MSELoss()
    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=5,
        min_lr=1e-7
    )

    
    best_val_loss = float('inf')
    best_epoch = 0
    no_improve_count = 0
    model = model.to(device)
    
    train_losses = []
    val_losses = []
    

    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        

        
        for batch in train_loader:
            drugA_feat = batch['drugA_feat'].to(device)
            drugB_feat = batch['drugB_feat'].to(device)
            cell_feat = batch['cell_feat'].to(device)
            combo_feat = batch['combo_feat'].to(device)
            target = batch['target'].to(device)
            drugA_conc = batch['drugA_conc'].to(device)
            drugB_conc = batch['drugB_conc'].to(device)
            single_resp_1 = batch['single_resp_1'].to(device)
            single_resp_2 = batch['single_resp_2'].to(device)
            indices = batch['index'].numpy()
            
            optimizer.zero_grad()
            
            theta1, theta2, epsilon, P_direct = model(drugA_feat, drugB_feat, cell_feat, combo_feat, drugA_conc, drugB_conc)

            P_abg = theta1 * single_resp_1 + theta2 * single_resp_2 + epsilon

            P_final = select_ablation_prediction(P_abg, P_direct, ablation_mode)
            loss = criterion(P_final, target)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * drugA_feat.size(0)
            

        
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        

        val_loss, val_metrics, val_results = evaluate_model(
            model, val_loader, val_df, epoch + 1, ablation_mode
        )
        val_losses.append(val_loss)
        

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, LR: {current_lr:.8f}')
        print(f'Val Metrics - MSE: {val_metrics["mse"]:.4f}, RMSE: {val_metrics["rmse"]:.4f}, '
              f'MAE: {val_metrics["mae"]:.4f}, PCC: {val_metrics["pcc"]:.4f}, R2: {val_metrics["r2"]:.4f}')  
        if val_loss < best_val_loss - min_delta:
            best_val_loss = val_loss
            no_improve_count = 0
            best_epoch = epoch + 1
            torch.save(model.state_dict(), checkpoint_path)
            print(f"Saved best model at epoch {epoch+1}, Val Loss: {best_val_loss:.4f}")
        else:
            no_improve_count += 1
            print(f"No improvement count: {no_improve_count}/{early_stop_patience}")

        if no_improve_count >= early_stop_patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    plt.figure(figsize=(10, 5))
    x_axis = range(1, len(train_losses) + 1)
    plt.plot(x_axis, train_losses, label='Train Loss')
    plt.plot(x_axis, val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss - {ablation_mode} (1-X/X0)')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'loss_curve_ablation_{ablation_mode}_seed{SEED}.png')
    plt.close()

    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    return model, train_losses, val_losses, best_epoch


def evaluate_model(model, data_loader, data_df, epoch, ablation_mode, save_results=True):
    model.eval()
    total_loss = 0.0
    all_preds = []
    all_targets = []
    results = []
    
    with torch.no_grad():
        for batch in data_loader:
            drugA_feat = batch['drugA_feat'].to(device)
            drugB_feat = batch['drugB_feat'].to(device)
            cell_feat = batch['cell_feat'].to(device)
            combo_feat = batch['combo_feat'].to(device)
            target = batch['target'].to(device)
            drugA_conc = batch['drugA_conc'].to(device)
            drugB_conc = batch['drugB_conc'].to(device)
            single_resp_1 = batch['single_resp_1'].to(device)
            single_resp_2 = batch['single_resp_2'].to(device)
            indices = batch['index'].numpy()
            
            theta1, theta2, epsilon, P_direct = model(drugA_feat, drugB_feat, cell_feat, combo_feat, drugA_conc, drugB_conc)

            P_abg = theta1 * single_resp_1 + theta2 * single_resp_2 + epsilon

            P_final = select_ablation_prediction(P_abg, P_direct, ablation_mode)
            
            all_preds.extend(P_final.cpu().numpy().flatten())
            all_targets.extend(target.cpu().numpy().flatten())
            
            loss = nn.MSELoss()(P_final, target)
            total_loss += loss.item() * drugA_feat.size(0)
            

            theta1_np = theta1.cpu().numpy()
            theta2_np = theta2.cpu().numpy()
            epsilon_np = epsilon.cpu().numpy()
            pred_np = P_final.cpu().numpy()
            target_np = target.cpu().numpy()
            
            for j, idx in enumerate(indices):
                sample_data = data_df.iloc[idx]
                results.append({
                    'epoch': epoch,
                    'drugA_name': sample_data['drugA_name'],
                    'drugB_name': sample_data['drugB_name'],
                    'cell_line': sample_data['cell_line'],
                    'drugA_conc': sample_data['drugA_conc'],
                    'drugB_conc': sample_data['drugB_conc'],
                    'target': target_np[j],  
                    'prediction': pred_np[j],  
                    'ablation_mode': ablation_mode,
                    'single_resp_1': sample_data['single_resp_1'],
                    'single_resp_2': sample_data['single_resp_2'],
                    'theta1': theta1_np[j],
                    'theta2': theta2_np[j],
                    'epsilon': epsilon_np[j],
                    'set': 'validation'
                })
    
    total_loss /= len(data_loader.dataset)
    
    assert len(all_preds) == len(all_targets), f"预测值数量({len(all_preds)})与真实值数量({len(all_targets)})不匹配"
    
    mse = mean_squared_error(all_targets, all_preds)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(all_targets, all_preds)
    pcc, _ = pearsonr(all_targets, all_preds)
    r2 = r2_score(all_targets, all_preds)
    c_index = concordance_index(all_targets, all_preds)
    
    metrics = {
        'mse': mse,
        'rmse': rmse,
        'mae': mae,
        'pcc': pcc,
        'r2': r2,
        'c_index': c_index
    }
    
    return total_loss, metrics, results

def save_final_theta1_theta2_epsilon(model, data_loader, data_df, ablation_mode):
    model.eval()
    results = []
    
    with torch.no_grad():
        for batch in data_loader:

            indices = batch['index'].numpy()
            batch_data = data_df.iloc[indices]
            
            drugA_feat = batch['drugA_feat'].to(device)
            drugB_feat = batch['drugB_feat'].to(device)
            cell_feat = batch['cell_feat'].to(device)
            combo_feat = batch['combo_feat'].to(device)
            drugA_conc = batch['drugA_conc'].to(device)
            drugB_conc = batch['drugB_conc'].to(device)
            target = batch['target'].to(device)
            single_resp_1 = batch['single_resp_1'].to(device)
            single_resp_2 = batch['single_resp_2'].to(device)
            
            theta1, theta2, epsilon, P_direct = model(drugA_feat, drugB_feat, cell_feat, combo_feat, drugA_conc, drugB_conc)

            P_abg = theta1 * single_resp_1 + theta2 * single_resp_2 + epsilon

            P_final = select_ablation_prediction(P_abg, P_direct, ablation_mode)

            
            theta1_np = theta1.cpu().numpy().flatten()
            theta2_np = theta2.cpu().numpy().flatten()
            epsilon_np = epsilon.cpu().numpy().flatten()
            idb_np = P_abg.cpu().numpy().flatten()
            hpb_np = P_direct.cpu().numpy().flatten()
            pred_np = P_final.cpu().numpy().flatten()
            target_np = target.cpu().numpy().flatten()
            
            for j in range(len(theta1_np)):
                sample_data = batch_data.iloc[j]
                results.append({
                    'drugA_name': sample_data['drugA_name'],
                    'drugB_name': sample_data['drugB_name'],
                    'cell_line': sample_data['cell_line'],
                    'drugA_conc': sample_data['drugA_conc'],
                    'drugB_conc': sample_data['drugB_conc'],
                    'target': target_np[j],  
                    'prediction': pred_np[j],  
                    'idb_prediction': idb_np[j],
                    'hpb_prediction': hpb_np[j],
                    'ablation_mode': ablation_mode,
                    'single_resp_1': sample_data['single_resp_1'],  
                    'single_resp_2': sample_data['single_resp_2'],  
                    'theta1': theta1_np[j],
                    'theta2': theta2_np[j],
                    'epsilon': epsilon_np[j]
                })
    
    results_df = pd.DataFrame(results)
    column_order = [
        'drugA_name', 'drugB_name', 'cell_line',
        'drugA_conc', 'drugB_conc', 
        'target', 'prediction', 'idb_prediction', 'hpb_prediction', 'ablation_mode',
        'single_resp_1', 'single_resp_2',
        'theta1', 'theta2', 'epsilon'
    ]
    results_df = results_df[column_order]
    output_path = f'final_predictions_ablation_{ablation_mode}_seed{SEED}.csv'
    results_df.to_csv(output_path, index=False)
    print(f'Saved final predictions to {output_path}')


def main():
    combo_df, drug_features, cell_features = load_data()
    data_df = preprocess_data(combo_df, drug_features, cell_features)
    
    if len(data_df) == 0:
        print("No valid data samples after preprocessing. Exiting.")
        return
    
    sample = data_df.iloc[0]
    drug_feat_dim = drug_features.iloc[0].values[2:].astype(np.float32).shape[0]
    cell_feat_dim = cell_features.iloc[0].values.astype(np.float32).shape[0]
    print(f"Drug feature dimension: {drug_feat_dim}")
    print(f"Cell feature dimension: {cell_feat_dim}")
    

    train_df, val_df, test_df, split_summary = grouped_train_val_test_split(
        data_df, train_size=0.70, val_size=0.10, test_size=0.20, random_state=SEED
    )
    
    train_dataset = DrugCombinationDataset(train_df, drug_features, cell_features)
    val_dataset = DrugCombinationDataset(val_df, drug_features, cell_features)
    test_dataset = DrugCombinationDataset(test_df, drug_features, cell_features)
    print(f"Train dataset size: {len(train_dataset)}") 
    print(f"Validation dataset size: {len(val_dataset)}")
    print(f"Test dataset size: {len(test_dataset)}")
    
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

    split_summary.to_csv(f'ablation_split_summary_seed{SEED}.csv', index=False)
    ablation_results = []


    for ablation_mode in ABLATION_MODES:
        print('\n' + '=' * 80)
        print(f'Ablation mode: {ablation_mode} | seed={SEED}')
        print('=' * 80)
        set_global_seed(SEED)
        loader_generator = torch.Generator()
        loader_generator.manual_seed(SEED)
        train_loader = DataLoader(
            train_dataset, batch_size=8, shuffle=True, generator=loader_generator
        )

        model = DrugCombinationModel(
            drug_feat_dim=drug_feat_dim, cell_feat_dim=cell_feat_dim
        )
        trained_model, train_losses, val_losses, best_epoch = train_model(
            model, train_loader, val_loader, train_df, val_df,
            ablation_mode=ablation_mode, epochs=100, lr=5e-5
        )

        final_loss, final_metrics, _ = evaluate_model(
            trained_model, test_loader, test_df, best_epoch, ablation_mode
        )
        print(f'\nFinal Test Metrics - {ablation_mode} (1-X/X0):')
        print(f'MSE: {final_metrics["mse"]:.6f}')
        print(f'RMSE: {final_metrics["rmse"]:.6f}')
        print(f'MAE: {final_metrics["mae"]:.6f}')
        print(f'PCC: {final_metrics["pcc"]:.6f}')
        print(f'R2: {final_metrics["r2"]:.6f}')
        print(f'C-index: {final_metrics["c_index"]:.6f}')

        final_model_path = f'final_model_ablation_{ablation_mode}_seed{SEED}.pth'
        torch.save(trained_model.state_dict(), final_model_path)
        save_final_theta1_theta2_epsilon(
            trained_model, test_loader, test_df, ablation_mode
        )

        ablation_results.append({
            'seed': SEED,
            'ablation_mode': ablation_mode,
            'best_epoch': best_epoch,
            **final_metrics,
            'train_samples': len(train_df),
            'val_samples': len(val_df),
            'test_samples': len(test_df),
            'train_groups': train_df['surface_id'].nunique(),
            'val_groups': val_df['surface_id'].nunique(),
            'test_groups': test_df['surface_id'].nunique()
        })

        del model, trained_model
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    ablation_results_df = pd.DataFrame(ablation_results)
    summary_path = f'ablation_idb_hpb_metrics_seed{SEED}.csv'
    ablation_results_df.to_csv(summary_path, index=False)
    print(f'\nSaved ablation summary to {summary_path}')
    print(ablation_results_df.to_string(index=False))

if __name__ == '__main__':
    main()
# Out:
# Using device: cuda
# Notebook working directory: e:\Research\DecoDoseNet\code
# Data directory: E:\Research\DecoDoseNet\code\data
# Skipped 16272 samples due to missing features
# Drug feature dimension: 6890
# Cell feature dimension: 977
#
# Grouped split summary (Drug pair + Cell line):
#      split  samples  surface_groups  sample_percent  group_percent
#      Train   149952            9247           69.94          69.99
# Validation    21488            1322           10.02          10.01
#       Test    42976            2643           20.04          20.00
#
# Leakage audit passed:
#   Train ∩ Validation groups = 0
#   Train ∩ Test groups       = 0
#   Validation ∩ Test groups  = 0
# Train dataset size: 149952
# Validation dataset size: 21488
# Test dataset size: 42976
#
# ================================================================================
# Ablation mode: idb_only | seed=42
# ================================================================================
# Epoch 1/100, Train Loss: 0.0174, Val Loss: 0.0146, LR: 0.00005000
# Val Metrics - MSE: 0.0146, RMSE: 0.1207, MAE: 0.0887, PCC: 0.9174, R2: 0.8405
# Saved best model at epoch 1, Val Loss: 0.0146
# Epoch 2/100, Train Loss: 0.0136, Val Loss: 0.0133, LR: 0.00005000
# Val Metrics - MSE: 0.0133, RMSE: 0.1153, MAE: 0.0842, PCC: 0.9248, R2: 0.8543
# Saved best model at epoch 2, Val Loss: 0.0133
# Epoch 3/100, Train Loss: 0.0120, Val Loss: 0.0123, LR: 0.00005000
# Val Metrics - MSE: 0.0123, RMSE: 0.1110, MAE: 0.0797, PCC: 0.9307, R2: 0.8649
# Saved best model at epoch 3, Val Loss: 0.0123
# Epoch 4/100, Train Loss: 0.0107, Val Loss: 0.0118, LR: 0.00005000
# Val Metrics - MSE: 0.0118, RMSE: 0.1088, MAE: 0.0780, PCC: 0.9331, R2: 0.8703
# Saved best model at epoch 4, Val Loss: 0.0118
# Epoch 5/100, Train Loss: 0.0096, Val Loss: 0.0110, LR: 0.00005000
# Val Metrics - MSE: 0.0110, RMSE: 0.1048, MAE: 0.0751, PCC: 0.9379, R2: 0.8796
# Saved best model at epoch 5, Val Loss: 0.0110
# Epoch 6/100, Train Loss: 0.0088, Val Loss: 0.0103, LR: 0.00005000
# Val Metrics - MSE: 0.0103, RMSE: 0.1013, MAE: 0.0725, PCC: 0.9422, R2: 0.8876
# Saved best model at epoch 6, Val Loss: 0.0103
# Epoch 7/100, Train Loss: 0.0082, Val Loss: 0.0102, LR: 0.00005000
# Val Metrics - MSE: 0.0102, RMSE: 0.1009, MAE: 0.0720, PCC: 0.9427, R2: 0.8885
# Saved best model at epoch 7, Val Loss: 0.0102
# Epoch 8/100, Train Loss: 0.0077, Val Loss: 0.0094, LR: 0.00005000
# Val Metrics - MSE: 0.0094, RMSE: 0.0971, MAE: 0.0691, PCC: 0.9470, R2: 0.8967
# Saved best model at epoch 8, Val Loss: 0.0094
# Epoch 9/100, Train Loss: 0.0073, Val Loss: 0.0095, LR: 0.00005000
# Val Metrics - MSE: 0.0095, RMSE: 0.0976, MAE: 0.0690, PCC: 0.9466, R2: 0.8957
# No improvement count: 1/10
# Epoch 10/100, Train Loss: 0.0070, Val Loss: 0.0093, LR: 0.00005000
# Val Metrics - MSE: 0.0093, RMSE: 0.0963, MAE: 0.0679, PCC: 0.9479, R2: 0.8984
# Saved best model at epoch 10, Val Loss: 0.0093
# Epoch 11/100, Train Loss: 0.0067, Val Loss: 0.0091, LR: 0.00005000
# Val Metrics - MSE: 0.0091, RMSE: 0.0956, MAE: 0.0674, PCC: 0.9487, R2: 0.9000
# Saved best model at epoch 11, Val Loss: 0.0091
# Epoch 12/100, Train Loss: 0.0065, Val Loss: 0.0090, LR: 0.00005000
# Val Metrics - MSE: 0.0090, RMSE: 0.0949, MAE: 0.0664, PCC: 0.9495, R2: 0.9013
# Saved best model at epoch 12, Val Loss: 0.0090
# Epoch 13/100, Train Loss: 0.0063, Val Loss: 0.0089, LR: 0.00005000
# Val Metrics - MSE: 0.0089, RMSE: 0.0941, MAE: 0.0662, PCC: 0.9503, R2: 0.9030
# Saved best model at epoch 13, Val Loss: 0.0089
# Epoch 14/100, Train Loss: 0.0061, Val Loss: 0.0088, LR: 0.00005000
# Val Metrics - MSE: 0.0088, RMSE: 0.0940, MAE: 0.0658, PCC: 0.9506, R2: 0.9031
# Saved best model at epoch 14, Val Loss: 0.0088
# Epoch 15/100, Train Loss: 0.0060, Val Loss: 0.0091, LR: 0.00005000
# Val Metrics - MSE: 0.0091, RMSE: 0.0953, MAE: 0.0670, PCC: 0.9491, R2: 0.9005
# No improvement count: 1/10
# Epoch 16/100, Train Loss: 0.0058, Val Loss: 0.0087, LR: 0.00005000
# Val Metrics - MSE: 0.0087, RMSE: 0.0934, MAE: 0.0651, PCC: 0.9510, R2: 0.9044
# Saved best model at epoch 16, Val Loss: 0.0087
# Epoch 17/100, Train Loss: 0.0057, Val Loss: 0.0088, LR: 0.00005000
# Val Metrics - MSE: 0.0088, RMSE: 0.0939, MAE: 0.0664, PCC: 0.9508, R2: 0.9034
# No improvement count: 1/10
# Epoch 18/100, Train Loss: 0.0056, Val Loss: 0.0085, LR: 0.00005000
# Val Metrics - MSE: 0.0085, RMSE: 0.0920, MAE: 0.0648, PCC: 0.9527, R2: 0.9072
# Saved best model at epoch 18, Val Loss: 0.0085
# Epoch 19/100, Train Loss: 0.0054, Val Loss: 0.0083, LR: 0.00005000
# Val Metrics - MSE: 0.0083, RMSE: 0.0912, MAE: 0.0634, PCC: 0.9536, R2: 0.9088
# Saved best model at epoch 19, Val Loss: 0.0083
# Epoch 20/100, Train Loss: 0.0053, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0905, MAE: 0.0638, PCC: 0.9541, R2: 0.9103
# Saved best model at epoch 20, Val Loss: 0.0082
# Epoch 21/100, Train Loss: 0.0052, Val Loss: 0.0084, LR: 0.00005000
# Val Metrics - MSE: 0.0084, RMSE: 0.0919, MAE: 0.0642, PCC: 0.9527, R2: 0.9075
# No improvement count: 1/10
# Epoch 22/100, Train Loss: 0.0051, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0907, MAE: 0.0640, PCC: 0.9540, R2: 0.9098
# No improvement count: 2/10
# Epoch 23/100, Train Loss: 0.0050, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0903, MAE: 0.0637, PCC: 0.9543, R2: 0.9107
# Saved best model at epoch 23, Val Loss: 0.0082
# Epoch 24/100, Train Loss: 0.0049, Val Loss: 0.0083, LR: 0.00005000
# Val Metrics - MSE: 0.0083, RMSE: 0.0912, MAE: 0.0633, PCC: 0.9540, R2: 0.9089
# No improvement count: 1/10
# Epoch 25/100, Train Loss: 0.0048, Val Loss: 0.0081, LR: 0.00005000
# Val Metrics - MSE: 0.0081, RMSE: 0.0897, MAE: 0.0628, PCC: 0.9549, R2: 0.9118
# Saved best model at epoch 25, Val Loss: 0.0081
# Epoch 26/100, Train Loss: 0.0047, Val Loss: 0.0081, LR: 0.00005000
# Val Metrics - MSE: 0.0081, RMSE: 0.0901, MAE: 0.0626, PCC: 0.9546, R2: 0.9111
# No improvement count: 1/10
# Epoch 27/100, Train Loss: 0.0046, Val Loss: 0.0081, LR: 0.00005000
# Val Metrics - MSE: 0.0081, RMSE: 0.0901, MAE: 0.0629, PCC: 0.9546, R2: 0.9112
# No improvement count: 2/10
# Epoch 28/100, Train Loss: 0.0045, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0907, MAE: 0.0632, PCC: 0.9541, R2: 0.9099
# No improvement count: 3/10
# Epoch 29/100, Train Loss: 0.0045, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0904, MAE: 0.0628, PCC: 0.9542, R2: 0.9104
# No improvement count: 4/10
# Epoch 30/100, Train Loss: 0.0044, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0904, MAE: 0.0625, PCC: 0.9544, R2: 0.9105
# No improvement count: 5/10
# Epoch 31/100, Train Loss: 0.0043, Val Loss: 0.0080, LR: 0.00005000
# Val Metrics - MSE: 0.0080, RMSE: 0.0897, MAE: 0.0627, PCC: 0.9550, R2: 0.9119
# Saved best model at epoch 31, Val Loss: 0.0080
# Epoch 32/100, Train Loss: 0.0042, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0884, MAE: 0.0614, PCC: 0.9563, R2: 0.9144
# Saved best model at epoch 32, Val Loss: 0.0078
# Epoch 33/100, Train Loss: 0.0042, Val Loss: 0.0080, LR: 0.00005000
# Val Metrics - MSE: 0.0080, RMSE: 0.0893, MAE: 0.0618, PCC: 0.9554, R2: 0.9127
# No improvement count: 1/10
# Epoch 34/100, Train Loss: 0.0041, Val Loss: 0.0077, LR: 0.00005000
# Val Metrics - MSE: 0.0077, RMSE: 0.0875, MAE: 0.0609, PCC: 0.9572, R2: 0.9162
# Saved best model at epoch 34, Val Loss: 0.0077
# Epoch 35/100, Train Loss: 0.0040, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0882, MAE: 0.0615, PCC: 0.9564, R2: 0.9147
# No improvement count: 1/10
# Epoch 36/100, Train Loss: 0.0040, Val Loss: 0.0077, LR: 0.00005000
# Val Metrics - MSE: 0.0077, RMSE: 0.0880, MAE: 0.0611, PCC: 0.9567, R2: 0.9152
# No improvement count: 2/10
# Epoch 37/100, Train Loss: 0.0039, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0881, MAE: 0.0613, PCC: 0.9566, R2: 0.9151
# No improvement count: 3/10
# Epoch 38/100, Train Loss: 0.0039, Val Loss: 0.0079, LR: 0.00005000
# Val Metrics - MSE: 0.0079, RMSE: 0.0889, MAE: 0.0621, PCC: 0.9560, R2: 0.9134
# No improvement count: 4/10
# Epoch 39/100, Train Loss: 0.0038, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0883, MAE: 0.0614, PCC: 0.9564, R2: 0.9146
# No improvement count: 5/10
# Epoch 40/100, Train Loss: 0.0038, Val Loss: 0.0079, LR: 0.00002500
# Val Metrics - MSE: 0.0079, RMSE: 0.0888, MAE: 0.0617, PCC: 0.9559, R2: 0.9137
# No improvement count: 6/10
# Epoch 41/100, Train Loss: 0.0033, Val Loss: 0.0078, LR: 0.00002500
# Val Metrics - MSE: 0.0078, RMSE: 0.0881, MAE: 0.0611, PCC: 0.9566, R2: 0.9149
# No improvement count: 7/10
# Epoch 42/100, Train Loss: 0.0033, Val Loss: 0.0077, LR: 0.00002500
# Val Metrics - MSE: 0.0077, RMSE: 0.0876, MAE: 0.0606, PCC: 0.9571, R2: 0.9159
# No improvement count: 8/10
# Epoch 43/100, Train Loss: 0.0032, Val Loss: 0.0075, LR: 0.00002500
# Val Metrics - MSE: 0.0075, RMSE: 0.0868, MAE: 0.0598, PCC: 0.9580, R2: 0.9175
# Saved best model at epoch 43, Val Loss: 0.0075
# Epoch 44/100, Train Loss: 0.0032, Val Loss: 0.0077, LR: 0.00002500
# Val Metrics - MSE: 0.0077, RMSE: 0.0877, MAE: 0.0606, PCC: 0.9571, R2: 0.9157
# No improvement count: 1/10
# Epoch 45/100, Train Loss: 0.0031, Val Loss: 0.0076, LR: 0.00002500
# Val Metrics - MSE: 0.0076, RMSE: 0.0870, MAE: 0.0605, PCC: 0.9577, R2: 0.9171
# No improvement count: 2/10
# Epoch 46/100, Train Loss: 0.0031, Val Loss: 0.0077, LR: 0.00002500
# Val Metrics - MSE: 0.0077, RMSE: 0.0877, MAE: 0.0609, PCC: 0.9572, R2: 0.9157
# No improvement count: 3/10
# Epoch 47/100, Train Loss: 0.0031, Val Loss: 0.0076, LR: 0.00002500
# Val Metrics - MSE: 0.0076, RMSE: 0.0872, MAE: 0.0608, PCC: 0.9577, R2: 0.9168
# No improvement count: 4/10
# Epoch 48/100, Train Loss: 0.0030, Val Loss: 0.0078, LR: 0.00002500
# Val Metrics - MSE: 0.0078, RMSE: 0.0882, MAE: 0.0612, PCC: 0.9565, R2: 0.9147
# No improvement count: 5/10
# Epoch 49/100, Train Loss: 0.0030, Val Loss: 0.0077, LR: 0.00001250
# Val Metrics - MSE: 0.0077, RMSE: 0.0879, MAE: 0.0610, PCC: 0.9568, R2: 0.9153
# No improvement count: 6/10
# Epoch 50/100, Train Loss: 0.0028, Val Loss: 0.0076, LR: 0.00001250
# Val Metrics - MSE: 0.0076, RMSE: 0.0872, MAE: 0.0606, PCC: 0.9575, R2: 0.9168
# No improvement count: 7/10
# Epoch 51/100, Train Loss: 0.0027, Val Loss: 0.0077, LR: 0.00001250
# Val Metrics - MSE: 0.0077, RMSE: 0.0878, MAE: 0.0608, PCC: 0.9570, R2: 0.9155
# No improvement count: 8/10
# Epoch 52/100, Train Loss: 0.0027, Val Loss: 0.0077, LR: 0.00001250
# Val Metrics - MSE: 0.0077, RMSE: 0.0875, MAE: 0.0610, PCC: 0.9572, R2: 0.9161
# No improvement count: 9/10
# Epoch 53/100, Train Loss: 0.0027, Val Loss: 0.0078, LR: 0.00001250
# Val Metrics - MSE: 0.0078, RMSE: 0.0885, MAE: 0.0615, PCC: 0.9563, R2: 0.9143
# No improvement count: 10/10
# Early stopping at epoch 53
#
# Final Test Metrics - idb_only (1-X/X0):
# MSE: 0.007885
# RMSE: 0.088797
# MAE: 0.060891
# PCC: 0.957306
# R2: 0.916178
# C-index: 0.917183
# Saved final predictions to final_predictions_ablation_idb_only_seed42.csv
#
# ================================================================================
# Ablation mode: hpb_only | seed=42
# ================================================================================
# Epoch 1/100, Train Loss: 0.0587, Val Loss: 0.0436, LR: 0.00005000
# Val Metrics - MSE: 0.0436, RMSE: 0.2089, MAE: 0.1658, PCC: 0.7279, R2: 0.5219
# Saved best model at epoch 1, Val Loss: 0.0436
# Epoch 2/100, Train Loss: 0.0340, Val Loss: 0.0316, LR: 0.00005000
# Val Metrics - MSE: 0.0316, RMSE: 0.1778, MAE: 0.1352, PCC: 0.8301, R2: 0.6537
# Saved best model at epoch 2, Val Loss: 0.0316
# Epoch 3/100, Train Loss: 0.0225, Val Loss: 0.0188, LR: 0.00005000
# Val Metrics - MSE: 0.0188, RMSE: 0.1371, MAE: 0.1007, PCC: 0.8965, R2: 0.7941
# Saved best model at epoch 3, Val Loss: 0.0188
# Epoch 4/100, Train Loss: 0.0161, Val Loss: 0.0156, LR: 0.00005000
# Val Metrics - MSE: 0.0156, RMSE: 0.1249, MAE: 0.0901, PCC: 0.9114, R2: 0.8290
# Saved best model at epoch 4, Val Loss: 0.0156
# Epoch 5/100, Train Loss: 0.0124, Val Loss: 0.0129, LR: 0.00005000
# Val Metrics - MSE: 0.0129, RMSE: 0.1135, MAE: 0.0792, PCC: 0.9282, R2: 0.8590
# Saved best model at epoch 5, Val Loss: 0.0129
# Epoch 6/100, Train Loss: 0.0102, Val Loss: 0.0132, LR: 0.00005000
# Val Metrics - MSE: 0.0132, RMSE: 0.1151, MAE: 0.0798, PCC: 0.9253, R2: 0.8550
# No improvement count: 1/10
# Epoch 7/100, Train Loss: 0.0088, Val Loss: 0.0105, LR: 0.00005000
# Val Metrics - MSE: 0.0105, RMSE: 0.1024, MAE: 0.0700, PCC: 0.9410, R2: 0.8851
# Saved best model at epoch 7, Val Loss: 0.0105
# Epoch 8/100, Train Loss: 0.0078, Val Loss: 0.0096, LR: 0.00005000
# Val Metrics - MSE: 0.0096, RMSE: 0.0980, MAE: 0.0678, PCC: 0.9461, R2: 0.8948
# Saved best model at epoch 8, Val Loss: 0.0096
# Epoch 9/100, Train Loss: 0.0070, Val Loss: 0.0092, LR: 0.00005000
# Val Metrics - MSE: 0.0092, RMSE: 0.0960, MAE: 0.0646, PCC: 0.9483, R2: 0.8991
# Saved best model at epoch 9, Val Loss: 0.0092
# Epoch 10/100, Train Loss: 0.0064, Val Loss: 0.0091, LR: 0.00005000
# Val Metrics - MSE: 0.0091, RMSE: 0.0953, MAE: 0.0640, PCC: 0.9491, R2: 0.9005
# Saved best model at epoch 10, Val Loss: 0.0091
# Epoch 11/100, Train Loss: 0.0060, Val Loss: 0.0086, LR: 0.00005000
# Val Metrics - MSE: 0.0086, RMSE: 0.0929, MAE: 0.0617, PCC: 0.9516, R2: 0.9055
# Saved best model at epoch 11, Val Loss: 0.0086
# Epoch 12/100, Train Loss: 0.0056, Val Loss: 0.0106, LR: 0.00005000
# Val Metrics - MSE: 0.0106, RMSE: 0.1028, MAE: 0.0710, PCC: 0.9440, R2: 0.8842
# No improvement count: 1/10
# Epoch 13/100, Train Loss: 0.0053, Val Loss: 0.0081, LR: 0.00005000
# Val Metrics - MSE: 0.0081, RMSE: 0.0898, MAE: 0.0600, PCC: 0.9551, R2: 0.9117
# Saved best model at epoch 13, Val Loss: 0.0081
# Epoch 14/100, Train Loss: 0.0051, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0904, MAE: 0.0590, PCC: 0.9544, R2: 0.9106
# No improvement count: 1/10
# Epoch 15/100, Train Loss: 0.0049, Val Loss: 0.0077, LR: 0.00005000
# Val Metrics - MSE: 0.0077, RMSE: 0.0877, MAE: 0.0568, PCC: 0.9573, R2: 0.9158
# Saved best model at epoch 15, Val Loss: 0.0077
# Epoch 16/100, Train Loss: 0.0047, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0886, MAE: 0.0580, PCC: 0.9561, R2: 0.9141
# No improvement count: 1/10
# Epoch 17/100, Train Loss: 0.0045, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0881, MAE: 0.0580, PCC: 0.9569, R2: 0.9151
# No improvement count: 2/10
# Epoch 18/100, Train Loss: 0.0044, Val Loss: 0.0076, LR: 0.00005000
# Val Metrics - MSE: 0.0076, RMSE: 0.0871, MAE: 0.0573, PCC: 0.9582, R2: 0.9170
# Saved best model at epoch 18, Val Loss: 0.0076
# Epoch 19/100, Train Loss: 0.0042, Val Loss: 0.0082, LR: 0.00005000
# Val Metrics - MSE: 0.0082, RMSE: 0.0908, MAE: 0.0608, PCC: 0.9569, R2: 0.9098
# No improvement count: 1/10
# Epoch 20/100, Train Loss: 0.0041, Val Loss: 0.0073, LR: 0.00005000
# Val Metrics - MSE: 0.0073, RMSE: 0.0852, MAE: 0.0551, PCC: 0.9599, R2: 0.9204
# Saved best model at epoch 20, Val Loss: 0.0073
# Epoch 21/100, Train Loss: 0.0040, Val Loss: 0.0076, LR: 0.00005000
# Val Metrics - MSE: 0.0076, RMSE: 0.0869, MAE: 0.0576, PCC: 0.9585, R2: 0.9172
# No improvement count: 1/10
# Epoch 22/100, Train Loss: 0.0039, Val Loss: 0.0071, LR: 0.00005000
# Val Metrics - MSE: 0.0071, RMSE: 0.0843, MAE: 0.0546, PCC: 0.9606, R2: 0.9222
# Saved best model at epoch 22, Val Loss: 0.0071
# Epoch 23/100, Train Loss: 0.0038, Val Loss: 0.0069, LR: 0.00005000
# Val Metrics - MSE: 0.0069, RMSE: 0.0829, MAE: 0.0539, PCC: 0.9620, R2: 0.9248
# Saved best model at epoch 23, Val Loss: 0.0069
# Epoch 24/100, Train Loss: 0.0038, Val Loss: 0.0068, LR: 0.00005000
# Val Metrics - MSE: 0.0068, RMSE: 0.0822, MAE: 0.0547, PCC: 0.9626, R2: 0.9260
# Saved best model at epoch 24, Val Loss: 0.0068
# Epoch 25/100, Train Loss: 0.0036, Val Loss: 0.0067, LR: 0.00005000
# Val Metrics - MSE: 0.0067, RMSE: 0.0817, MAE: 0.0532, PCC: 0.9628, R2: 0.9268
# Saved best model at epoch 25, Val Loss: 0.0067
# Epoch 26/100, Train Loss: 0.0035, Val Loss: 0.0069, LR: 0.00005000
# Val Metrics - MSE: 0.0069, RMSE: 0.0829, MAE: 0.0523, PCC: 0.9620, R2: 0.9248
# No improvement count: 1/10
# Epoch 27/100, Train Loss: 0.0034, Val Loss: 0.0078, LR: 0.00005000
# Val Metrics - MSE: 0.0078, RMSE: 0.0881, MAE: 0.0553, PCC: 0.9573, R2: 0.9151
# No improvement count: 2/10
# Epoch 28/100, Train Loss: 0.0033, Val Loss: 0.0068, LR: 0.00005000
# Val Metrics - MSE: 0.0068, RMSE: 0.0826, MAE: 0.0528, PCC: 0.9619, R2: 0.9252
# No improvement count: 3/10
# Epoch 29/100, Train Loss: 0.0033, Val Loss: 0.0071, LR: 0.00005000
# Val Metrics - MSE: 0.0071, RMSE: 0.0844, MAE: 0.0535, PCC: 0.9611, R2: 0.9219
# No improvement count: 4/10
# Epoch 30/100, Train Loss: 0.0032, Val Loss: 0.0068, LR: 0.00005000
# Val Metrics - MSE: 0.0068, RMSE: 0.0826, MAE: 0.0533, PCC: 0.9621, R2: 0.9253
# No improvement count: 5/10
# Epoch 31/100, Train Loss: 0.0032, Val Loss: 0.0067, LR: 0.00005000
# Val Metrics - MSE: 0.0067, RMSE: 0.0816, MAE: 0.0534, PCC: 0.9635, R2: 0.9271
# Saved best model at epoch 31, Val Loss: 0.0067
# Epoch 32/100, Train Loss: 0.0031, Val Loss: 0.0066, LR: 0.00005000
# Val Metrics - MSE: 0.0066, RMSE: 0.0813, MAE: 0.0528, PCC: 0.9635, R2: 0.9277
# Saved best model at epoch 32, Val Loss: 0.0066
# Epoch 33/100, Train Loss: 0.0030, Val Loss: 0.0071, LR: 0.00005000
# Val Metrics - MSE: 0.0071, RMSE: 0.0845, MAE: 0.0534, PCC: 0.9606, R2: 0.9218
# No improvement count: 1/10
# Epoch 34/100, Train Loss: 0.0030, Val Loss: 0.0067, LR: 0.00005000
# Val Metrics - MSE: 0.0067, RMSE: 0.0821, MAE: 0.0520, PCC: 0.9624, R2: 0.9262
# No improvement count: 2/10
# Epoch 35/100, Train Loss: 0.0029, Val Loss: 0.0067, LR: 0.00005000
# Val Metrics - MSE: 0.0067, RMSE: 0.0816, MAE: 0.0528, PCC: 0.9632, R2: 0.9270
# No improvement count: 3/10
# Epoch 36/100, Train Loss: 0.0029, Val Loss: 0.0068, LR: 0.00005000
# Val Metrics - MSE: 0.0068, RMSE: 0.0823, MAE: 0.0519, PCC: 0.9622, R2: 0.9257
# No improvement count: 4/10
# Epoch 37/100, Train Loss: 0.0028, Val Loss: 0.0069, LR: 0.00005000
# Val Metrics - MSE: 0.0069, RMSE: 0.0833, MAE: 0.0526, PCC: 0.9613, R2: 0.9239
# No improvement count: 5/10
# Epoch 38/100, Train Loss: 0.0027, Val Loss: 0.0073, LR: 0.00002500
# Val Metrics - MSE: 0.0073, RMSE: 0.0856, MAE: 0.0540, PCC: 0.9605, R2: 0.9198
# No improvement count: 6/10
# Epoch 39/100, Train Loss: 0.0022, Val Loss: 0.0061, LR: 0.00002500
# Val Metrics - MSE: 0.0061, RMSE: 0.0782, MAE: 0.0498, PCC: 0.9659, R2: 0.9330
# Saved best model at epoch 39, Val Loss: 0.0061
# Epoch 40/100, Train Loss: 0.0020, Val Loss: 0.0061, LR: 0.00002500
# Val Metrics - MSE: 0.0061, RMSE: 0.0781, MAE: 0.0497, PCC: 0.9662, R2: 0.9332
# Saved best model at epoch 40, Val Loss: 0.0061
# Epoch 41/100, Train Loss: 0.0020, Val Loss: 0.0059, LR: 0.00002500
# Val Metrics - MSE: 0.0059, RMSE: 0.0771, MAE: 0.0494, PCC: 0.9671, R2: 0.9349
# Saved best model at epoch 41, Val Loss: 0.0059
# Epoch 42/100, Train Loss: 0.0020, Val Loss: 0.0064, LR: 0.00002500
# Val Metrics - MSE: 0.0064, RMSE: 0.0797, MAE: 0.0502, PCC: 0.9646, R2: 0.9304
# No improvement count: 1/10
# Epoch 43/100, Train Loss: 0.0020, Val Loss: 0.0062, LR: 0.00002500
# Val Metrics - MSE: 0.0062, RMSE: 0.0788, MAE: 0.0496, PCC: 0.9656, R2: 0.9320
# No improvement count: 2/10
# Epoch 44/100, Train Loss: 0.0019, Val Loss: 0.0063, LR: 0.00002500
# Val Metrics - MSE: 0.0063, RMSE: 0.0793, MAE: 0.0495, PCC: 0.9650, R2: 0.9311
# No improvement count: 3/10
# Epoch 45/100, Train Loss: 0.0019, Val Loss: 0.0063, LR: 0.00002500
# Val Metrics - MSE: 0.0063, RMSE: 0.0794, MAE: 0.0496, PCC: 0.9649, R2: 0.9310
# No improvement count: 4/10
# Epoch 46/100, Train Loss: 0.0018, Val Loss: 0.0062, LR: 0.00002500
# Val Metrics - MSE: 0.0062, RMSE: 0.0790, MAE: 0.0496, PCC: 0.9652, R2: 0.9316
# No improvement count: 5/10
# Epoch 47/100, Train Loss: 0.0018, Val Loss: 0.0061, LR: 0.00001250
# Val Metrics - MSE: 0.0061, RMSE: 0.0778, MAE: 0.0489, PCC: 0.9663, R2: 0.9337
# No improvement count: 6/10
# Epoch 48/100, Train Loss: 0.0016, Val Loss: 0.0061, LR: 0.00001250
# Val Metrics - MSE: 0.0061, RMSE: 0.0779, MAE: 0.0488, PCC: 0.9663, R2: 0.9335
# No improvement count: 7/10
# Epoch 49/100, Train Loss: 0.0016, Val Loss: 0.0063, LR: 0.00001250
# Val Metrics - MSE: 0.0063, RMSE: 0.0791, MAE: 0.0490, PCC: 0.9652, R2: 0.9315
# No improvement count: 8/10
# Epoch 50/100, Train Loss: 0.0015, Val Loss: 0.0061, LR: 0.00001250
# Val Metrics - MSE: 0.0061, RMSE: 0.0784, MAE: 0.0496, PCC: 0.9662, R2: 0.9326
# No improvement count: 9/10
# Epoch 51/100, Train Loss: 0.0015, Val Loss: 0.0063, LR: 0.00001250
# Val Metrics - MSE: 0.0063, RMSE: 0.0794, MAE: 0.0492, PCC: 0.9652, R2: 0.9309
# No improvement count: 10/10
# Early stopping at epoch 51
#
# Final Test Metrics - hpb_only (1-X/X0):
# MSE: 0.006256
# RMSE: 0.079095
# MAE: 0.049379
# PCC: 0.966284
# R2: 0.933494
# C-index: 0.931733
# Saved final predictions to final_predictions_ablation_hpb_only_seed42.csv
#
# Saved ablation summary to ablation_idb_hpb_metrics_seed42.csv
#  seed ablation_mode  best_epoch      mse     rmse      mae      pcc       r2  c_index  train_samples  val_samples  test_samples  train_groups  val_groups  test_groups
#    42      idb_only          43 0.007885 0.088797 0.060891 0.957306 0.916178 0.917183         149952        21488         42976          9247        1322         2643
#    42      hpb_only          41 0.006256 0.079095 0.049379 0.966284 0.933494 0.931733         149952        21488         42976          9247        1322         2643
